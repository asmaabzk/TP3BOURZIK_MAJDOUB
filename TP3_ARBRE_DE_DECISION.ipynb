# %%
from sklearn.datasets import load_iris
import numpy as np
import pandas as pd

# %% [markdown]
# # Classification à l'aide d'arbre de décision:

# %%
#Import data Iris
iris = load_iris()
X, y = iris.data, iris.target

# %%
#Taille de Data
X.shape
# Out:
# (150, 4)

# %%
data=pd.DataFrame(iris.data)

# %%
#renommer  =les columns
dataIris=data.rename(columns={0:'longueurS',1:'largeurS',2:'longueurP',3:'largeurP'})

# %% [markdown]
# ### Calcul des mesures statistiques

# %%
# CALCUL DE LA MOYENNE

# %%
dataIris.describe()
# Out:
#         longueurS    largeurS   longueurP    largeurP
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.057333    3.758000    1.199333
# std      0.828066    0.435866    1.765298    0.762238
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
#CALCUL DE LA MOYENNE

# %%
print("La moyenne de la longueur de sépale est:",np.average(dataIris.longueurS))
# Out:
# La moyenne de la longueur de sépale est: 5.843333333333334

# %%
print("La moyenne de la largueur de sépale est:",np.average(dataIris.largeurS))
# Out:
# La moyenne de la largueur de sépale est: 3.0573333333333337

# %%
print("La moyenne de la longueur de pétale est:",np.average(dataIris.longueurP))
# Out:
# La moyenne de la longueur de pétale est: 3.7580000000000005

# %%
print("La moyenne de largeur de pétale est:",np.average(dataIris.largeurP))
# Out:
# La moyenne de largeur de pétale est: 1.1993333333333336

# %%
#CALCUL DE L'ECART TYPE

# %%
print("L'écart type de la longueur de sépale est:",np.std(dataIris.longueurS))
# Out:
# L'ecart type de la longueur de sépale est: 0.8253012917851409

# %%
print("L'écart type de la largueur de sépale est:",np.std(dataIris.largeurS))
# Out:
# L'ecart type de la largueur de sépale est: 0.43441096773549437

# %%
print("L'écart type de la longueur de pétale est:",np.std(dataIris.largeurP))
# Out:
# L'ecart type de la longueur de pétale est: 0.7596926279021594

# %%
print("L'écart type de largeur de pétale est:",np.std(dataIris.largeurP))

# %%
#DATAFRAME DE L'ENSEMBLE DE TARGET
cl=pd.DataFrame(y)
cl=cl.rename(columns={0:'Target'})
cl
# Out:
#      Target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 1 columns]

# %%
print(cl["Target"].value_counts())
# Out:
# 0    50
# 1    50
# 2    50
# Name: Target, dtype: int64

# %% [markdown]
# # Construction du modèle

# %%
#Split des données en 70% pour l'entrainement et 30% pour le test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7,
random_state=0)

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Plot de l'arbre de décision
tree.plot_tree(clf, filled=True)
# Out:
# [Text(0.4, 0.9, 'X[2] <= 2.35\ngini = 0.664\nsamples = 105\nvalue = [34, 32, 39]'),
#  Text(0.3, 0.7, 'gini = 0.0\nsamples = 34\nvalue = [34, 0, 0]'),
#  Text(0.5, 0.7, 'X[2] <= 4.95\ngini = 0.495\nsamples = 71\nvalue = [0, 32, 39]'),
#  Text(0.2, 0.5, 'X[3] <= 1.65\ngini = 0.161\nsamples = 34\nvalue = [0, 31, 3]'),
#  Text(0.1, 0.3, 'gini = 0.0\nsamples = 30\nvalue = [0, 30, 0]'),
#  Text(0.3, 0.3, 'X[1] <= 3.1\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.2, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.4, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8, 0.5, 'X[2] <= 5.05\ngini = 0.053\nsamples = 37\nvalue = [0, 1, 36]'),
#  Text(0.7, 0.3, 'X[1] <= 2.75\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.6, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.8, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9, 0.3, 'gini = 0.0\nsamples = 33\nvalue = [0, 0, 33]')]

# %%
clf.predict(X_test)
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0, 2, 1, 0, 2, 2, 1, 0, 2, 1, 1, 2, 0, 2, 0,
#        0])

# %%
clf.score(X_test, y_test)
# Out:
# 0.9777777777777777

# %%
clf1 = tree.DecisionTreeClassifier(max_depth=2)
clf1.fit(X_train, y_train)
#min_samples_leaf
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
tree.plot_tree(clf1, filled=True)
# Out:
# [Text(0.4, 0.8333333333333334, 'X[3] <= 0.75\ngini = 0.664\nsamples = 105\nvalue = [34, 32, 39]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 34\nvalue = [34, 0, 0]'),
#  Text(0.6, 0.5, 'X[2] <= 4.95\ngini = 0.495\nsamples = 71\nvalue = [0, 32, 39]'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.161\nsamples = 34\nvalue = [0, 31, 3]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.053\nsamples = 37\nvalue = [0, 1, 36]')]

# %%
clf21 = tree.DecisionTreeClassifier(min_samples_leaf = 5)
clf21.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(min_samples_leaf=5)

# %%
tree.plot_tree(clf21, filled=True)
# Out:
# [Text(0.4444444444444444, 0.9, 'X[3] <= 0.8\ngini = 0.667\nsamples = 142\nvalue = [47, 48, 47]'),
#  Text(0.3333333333333333, 0.7, 'gini = 0.0\nsamples = 47\nvalue = [47, 0, 0]'),
#  Text(0.5555555555555556, 0.7, 'X[3] <= 1.75\ngini = 0.5\nsamples = 95\nvalue = [0, 48, 47]'),
#  Text(0.3333333333333333, 0.5, 'X[2] <= 4.95\ngini = 0.174\nsamples = 52\nvalue = [0, 47, 5]'),
#  Text(0.2222222222222222, 0.3, 'X[0] <= 5.15\ngini = 0.043\nsamples = 46\nvalue = [0, 45, 1]'),
#  Text(0.1111111111111111, 0.1, 'gini = 0.32\nsamples = 5\nvalue = [0, 4, 1]'),
#  Text(0.3333333333333333, 0.1, 'gini = 0.0\nsamples = 41\nvalue = [0, 41, 0]'),
#  Text(0.4444444444444444, 0.3, 'gini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.7777777777777778, 0.5, 'X[0] <= 5.95\ngini = 0.045\nsamples = 43\nvalue = [0, 1, 42]'),
#  Text(0.6666666666666666, 0.3, 'gini = 0.278\nsamples = 6\nvalue = [0, 1, 5]'),
#  Text(0.8888888888888888, 0.3, 'gini = 0.0\nsamples = 37\nvalue = [0, 0, 37]')]

# %%
#Spli données 95% Train et 5% Test

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test= train_test_split(X,y,train_size=0.95,random_state=0)

# %%
from sklearn import tree
clf2 = tree.DecisionTreeClassifier()
clf2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
clf2.predict(X_test)
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1])

# %%
y_test
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1])

# %%
clf2.score(X_test, y_test)
# Out:
# 1.0

# %%
from sklearn.metrics import accuracy_score
print(f"Le taux d’éléments mal classifiés sur l’ensemble de test : {1-accuracy_score(y_test, clf.predict(X_test))} ")
# Out:
# Le taux d’éléments mal classifiés sur l’ensemble de test : 0.0

# %% [markdown]
# # Visualisation

# %%
import numpy as np
import matplotlib.pyplot as plt
# Paramètres
n_classes = 3
plot_colors = "bry" # blue-red-yellow
plot_step = 0.02
# Choisir les attributs longueur et largeur des pétales
pair = [2, 3]
# On ne garde seulement les deux attributs
X = iris.data[:, pair]
y = iris.target
# Apprentissage de l'arbre
clf = tree.DecisionTreeClassifier().fit(X, y)
# Affichage de la surface de décision
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step), np.arange(y_min,
y_max, plot_step))
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
cs = plt.contourf(xx, yy, Z, cmap=plt.cm.Paired)
plt.xlabel(iris.feature_names[pair[0]])
plt.ylabel(iris.feature_names[pair[1]])
plt.axis("tight")
# Affichage des points d'apprentissage
for i, color in zip(range(n_classes), plot_colors):
    idx = np.where(y == i)
    plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],cmap=plt.cm.Paired, edgecolor="black")
plt.axis("tight")
plt.suptitle("Decision surface of a decision tree using paired features")
plt.legend()
plt.show()

# %%
for k in range(0,4):
    for j in range(0,4):
        if(k!=j):
            pair = [k, j]
            X = iris.data[:, pair]
            y = iris.target
            # Apprentissage de l'arbre
            clf = tree.DecisionTreeClassifier().fit(X, y)
            x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
            y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
            xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step), np.arange(y_min,
                                                                           y_max, plot_step))
            Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
            Z = Z.reshape(xx.shape)
            cs = plt.contourf(xx, yy, Z, cmap=plt.cm.Paired)
            plt.xlabel(iris.feature_names[pair[0]])
            plt.ylabel(iris.feature_names[pair[1]])
            plt.axis("tight")
            for i, color in zip(range(n_classes), plot_colors):
                idx = np.where(y == i)
                plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],cmap=plt.cm.Paired, edgecolor="black")
            plt.axis("tight")
            plt.suptitle("Decision surface of a decision tree using paired features")
            plt.legend()
            plt.show()

# %% [markdown]
# # L'arbre de régression

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
# Créer les données d'apprentissage
np.random.seed(0)
X = np.sort(5 * np.random.rand(80, 1), axis=0)
y = np.sin(X).ravel()
fig = plt.figure(figsize=(12, 4))
fig.add_subplot(121)
plt.plot(X, y)
plt.title("Signal sinusoïdal pur")
# On ajoute un bruit aléatoire tous les 5 échantillons
y[::5] += 9* (0.5 - np.random.rand(16))
fig.add_subplot(122)
plt.plot(X, y)
plt.title("Signal sinusoïdal bruité")
# Out:
# Text(0.5, 1.0, 'Signal sinusoïdal bruité')

# %%
reg = DecisionTreeRegressor(max_depth=3)
reg.fit(X, y)
X_test = np.arange(0.0, 5.0, 0.01)[:, np.newaxis]
y_pred = reg.predict(X_test)
plt.figure()
plt.scatter(X, y, c="darkorange", label="Exemples d'apprentissage")
plt.plot(X_test, y_pred, color="cornflowerblue", label="Prédiction",
linewidth=2)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Régression par un arbre de décision")
plt.legend()
plt.show()

# %% [markdown]
# Regression Data Diabetes

# %%
from sklearn.datasets  import load_diabetes

# %%
#Import data
diabete= load_diabetes()
dataX,targetY = diabete.data, diabete.target

# %%
from sklearn.model_selection import train_test_split
X_train1, X_test1, y_train1, y_test1 = train_test_split(dataX,targetY, train_size=0.7,
random_state=0)

# %%
RT = DecisionTreeRegressor()
RT.fit(X_train1, y_train1)
y_predi = RT.predict(X_test1)

# %%
from math import *
from sklearn.metrics import mean_squared_error
rmse=np.sqrt(mean_squared_error(y_test,y_predi,squared=False))

# %%
print(rmse)
# Out:
# 8.801029134854048

# %%
from sklearn.model_selection import GridSearchCV
param=[{"max_depth":list(range(2,10))}]
GridSearchCV(DecisionTreeRegressor(),param)
RT.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
print(RT.get_depth)
# Out:
# <bound method BaseDecisionTree.get_depth of DecisionTreeRegressor(max_depth=3)>

# %%
y_predi=RT.predict(X_test)
